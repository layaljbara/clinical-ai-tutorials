# %%
import math
import torch
import torch.nn as nn 
import torch.nn.functional as F

torch.manual_seed(42)  ## Usually we need to randomize : Inside

# %%
tokens = ["cirrhosis", "pain", "fever", "improved", "a"]

logits = torch.tensor([
    3.0,
    2.2,
    1.4,
    0.7,
    0.2
])

probabilities = torch.softmax(logits, dim=-1)

for token, probability in zip(tokens, probabilities):
    print(token, probability.item())
# Out:
# cirrhosis 0.5517867207527161
# pain 0.2479337751865387
# fever 0.11140381544828415
# improved 0.055321503430604935
# a 0.033554188907146454

# %%
x=torch.ones(10)
dropout = nn.Dropout(0.5)
dropout(x)
# Out:
# tensor([0., 2., 2., 2., 0., 0., 2., 0., 2., 0.])
